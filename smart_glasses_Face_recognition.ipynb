# %%
import kagglehub
import shutil
import os
path = kagglehub.dataset_download("vasukipatel/face-recognition-dataset")

print("Path to dataset files:", path)



source_path = path
destination_path = '/content/'

if not os.path.exists(destination_path):
    os.makedirs(destination_path)

shutil.move(source_path, destination_path)

print(f"Data moved from {source_path} to {destination_path}")
# Out:
# ...
# 100%|██████████| 726M/726M [00:09<00:00, 84.4MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/vasukipatel/face-recognition-dataset/versions/1
# Data moved from /root/.cache/kagglehub/datasets/vasukipatel/face-recognition-dataset/versions/1 to /content/

# %%
# import tarfile

# tgz_file_path = '/content/3/lfw-funneled.tgz'

# extract_to_path = 'funneled/'

# with tarfile.open(tgz_file_path, 'r:gz') as tar:
#     tar.extractall(path=extract_to_path)

# print(f"Extracted contents to {extract_to_path}")
# Out:
# Extracted contents to funneled/

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# !pip install deepface

# %%
from deepface import DeepFace
import cv2
import os
# Out:
# 25-03-14 08:55:22 - Directory /root/.deepface has been created
# 25-03-14 08:55:22 - Directory /root/.deepface/weights has been created

# %%
main_folder = "/content/1/Faces/Faces"
main_folder_folders = os.listdir(main_folder)
main_folder_folders = sorted(main_folder_folders)
len(main_folder_folders)
# Out:
# 2562

# %%
main_folder_folders[0]
# Out:
# 'Akshay Kumar_0.jpg'

# %%
main_folder_folders[1]
# Out:
# 'Akshay Kumar_1.jpg'

# %%
result = DeepFace.verify(
  img1_path = f"/content/1/Faces/Faces/{main_folder_folders[0]}",
  img2_path = f"/content/1/Faces/Faces/{main_folder_folders[1]}",
  model_name = "Facenet",
  threshold = 0.5
)

# %%
result
# Out:
# {'verified': True,
#  'distance': 0.4999024125114033,
#  'threshold': 0.5,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 0,
#    'y': 1,
#    'w': 159,
#    'h': 158,
#    'left_eye': None,
#    'right_eye': None},
#   'img2': {'x': 2,
#    'y': 0,
#    'w': 157,
#    'h': 159,
#    'left_eye': (115, 59),
#    'right_eye': (42, 63)}},
#  'time': 0.94}

# %%
main_folder_folders[101]
# Out:
# 'Alexandra Daddario_55.jpg'

# %%
result = DeepFace.verify(
  img1_path = f"/content/1/Faces/Faces/{main_folder_folders[100]}",
  img2_path = f"/content/1/Faces/Faces/{main_folder_folders[101]}",
  model_name = "Facenet",
  threshold = 0.5
)

# %%
result
# Out:
# {'verified': True,
#  'distance': 0.24986075196919755,
#  'threshold': 0.5,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 0,
#    'y': 0,
#    'w': 159,
#    'h': 159,
#    'left_eye': (91, 55),
#    'right_eye': (30, 64)},
#   'img2': {'x': 0,
#    'y': 0,
#    'w': 159,
#    'h': 159,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 0.85}

# %%
# !pip install face_recognition

# %%
import face_recognition

image = face_recognition.load_image_file(f"/content/funneled/lfw_funneled/{main_images_folder[0]}/Wesley_Clark_0002.jpg")
face_locations = face_recognition.face_locations(image)

# %%
type(face_locations)
# Out:
# list

# %%
face_locations
# Out:
# [(80, 175, 187, 67)]

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

plt.imshow(image)
ax = plt.gca()

for (top, right, bottom, left) in face_locations:
    rect = Rectangle((left, top), right - left, bottom - top, linewidth=2, edgecolor='red', facecolor='none')
    ax.add_patch(rect)

plt.axis("off")
plt.show()

# %%
import face_recognition

image = face_recognition.load_image_file(f"/content/funneled/lfw_funneled/{main_images_folder[0]}/Wesley_Clark_0001.jpg")
face_locations = face_recognition.face_locations(image)

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

plt.imshow(image)
ax = plt.gca()

for (top, right, bottom, left) in face_locations:
    rect = Rectangle((left, top), right - left, bottom - top, linewidth=2, edgecolor='red', facecolor='none')
    ax.add_patch(rect)

plt.axis("off")
plt.show()
